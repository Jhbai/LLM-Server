# %%
import requests

def stream_lines(url, headers=None, params=None, timeout=30):
    with requests.post(url, headers=headers, params=params, stream=True, timeout=timeout) as r:
        r.raise_for_status()
        for line in r.iter_lines(decode_unicode=True):
            if line:
                print(line)

if __name__ == "__main__":
    stream_lines("http://127.0.0.1:8000/v1/chat/completions?uid=123&prompt=%E8%AB%8B%E8%87%AA%E6%88%91%E4%BB%8B%E7%B4%B9%E4%B8%80%E4%B8%8B")
# Out:
# 尊敬的各位讀者：
# 我是一個由 [您的名字] 創始者，並在 [您的工作領域] 服務的 [您的公司名稱]。
# 我專注於 [您的核心技能和專案]，並在 [您的工作經驗] 中，[您的工作經驗] 取得了 [您的工作成果]，並在 [您的工作領域] 取得了 [您的工作成果]。
# 我希望能夠在 [您的工作領域] 建立一個堅強、高效、有責任的團隊，並在 [您的公司] 積極貢獻到我的工作成果中。
# 我非常感謝 [您的公司] 提供的 [您的工作] 幫助我 [您的工作] 取得的 [您的工作成果]，並感謝 [您的公司] 提供的 [您的工作] 幫助我 [您的工作] 提升 [您的工作] 的 [您的工作成果]。
# 我期待在 [您的工作領域] 繼續我的工作，並在 [您的公司] 積極參與 [您的公司] 的 [您的工作] 發展中。
# 我期待與您再次發揮我的專業知識和技能，並為您的 [您的工作] 服務。
# 謝謝！
# [您的姓名]
# [您的電話]
# [您的電子郵件]
# [您的 LinkedIn 連結 (如果有)]

# %%
adict = {"abc": "test"}
adict.pop("abc"), adict
# Out:
# ('test', {})
